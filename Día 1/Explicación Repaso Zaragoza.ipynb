# %%
# VARIABLES
# CREAR VARIABLES
nombre_variable = 6

# USAR VARIABLES
print(nombre_variable)
# Out:
# 6

# %%
# TIPOS PRIMITIVOS
entero = -5
decimales = 6.5
verdadero = True
falso = False
texto = "Hola"

# %%
texto
# Out:
# 'Hola'

# %%
# ESTRUCTURAS DE DATOS
# LISTAS
lista = ["Hola",1232,True]

tuplas = ("Hola",1232,True)

conjunto = {"Hola",1232,True,"Hola"}

# %%
lista.append("Luis")
lista.append("Profe")
lista
# Out:
# ['Hola', 1232, True, 'Luis', 'Profe']

# %%
lista.insert(0,"Test")
lista
# Out:
# ['Test', 'Hola', 1232, True, 'Luis', 'Profe']

# %%
lista.add("Test")
lista

# %%
# OPERADORES

# OPERADORES ARITMÉTICOS
6 + 5
9 - 2
9 * 2
10 / 6
10 // 6
10 % 2
9 ** 6

# OPERADORES DE ASIGNACIÓN
letra = "b"
variable = 5

# OPERADORES DE COMPARACIÓN
variable == "5"
variable != 50
variable < 50
variable > 50
variable >= 50
vocales = ["a","e","i","o","u"]
letra in vocales
# Out:
# False

# %%
nuestra_velocidad = 120
maxima_velocidad = 120
if nuestra_velocidad < maxima_velocidad:
  print("Todo OK")
elif nuestra_velocidad == maxima_velocidad:
  print("Deja de acelerar")
else:
  print("Multita")
